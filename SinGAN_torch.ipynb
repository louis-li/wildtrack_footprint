# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive
# !pwd
# Out:
# /content/drive/My Drive
# /content/drive/My Drive

# %%
# !git clone https://github.com/tamarott/SinGAN.git
# Out:
# Cloning into 'SinGAN'...
# remote: Enumerating objects: 790, done.
# remote: Total 790 (delta 0), reused 0 (delta 0), pack-reused 790
# Receiving objects: 100% (790/790), 94.89 MiB | 20.14 MiB/s, done.
# Resolving deltas: 100% (304/304), done.

# %%
# %cd /content/drive/My Drive/SinGAN-Torch
# !pwd
# Out:
# /content/drive/My Drive/SinGAN-Torch
# /content/drive/My Drive/SinGAN-Torch

# %%
# !python -m pip install -r requirements.txt

# %%
# !pip install torch==1.4.0 torchvision==0.5.0 # only versions that will work with SinGAN
# Out:
# ...
#      |████████████████████████████████| 753.4MB 20kB/s
# ...
#      |████████████████████████████████| 4.0MB 56.2MB/s
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# ...

# %%
# need to manually update the training name in 'main_train.py' for now
! python main_train.py --input_name train.tif
# Out:
# Random Seed:  7184
# Traceback (most recent call last):
#   File "main_train.py", line 27, in <module>
#     real = functions.read_image(opt)
#   File "/content/drive/My Drive/SinGAN-Torch/SinGAN/functions.py", line 151, in read_image
#     x = np2torch(x,opt)
#   File "/content/drive/My Drive/SinGAN-Torch/SinGAN/functions.py", line 163, in np2torch
#     x = x[:,:,:,None]
# IndexError: too many indices for array

# %%
# %cd /content/drive/My Drive/SinGAN-Torch
# !pwd
! python random_samples.py  --input_name balloons.png --mode random_samples --gen_start_scale 8
# Out:
# /content/drive/My Drive/SinGAN-Torch
# /content/drive/My Drive/SinGAN-Torch
# Random Seed:  8668
# random samples for image balloons.png, start scale=8, already exist

# %%
# high resolution image
! python SR.py --input_name lion.jpg --sr_factor 4
# Out:
# Random Seed:  5305
# 4.000000
